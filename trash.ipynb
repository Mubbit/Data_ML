# %%
import pandas as pd 
case_list=pd.read_csv('case_list.txt')
case_list=case_list.rename({'Case_id':'case_id','판례내용':'prny'})
case_list.to_csv('case_list.csv',index=False)

# %%
import pandas as pd
case_list=pd.read_csv('case_list.csv')
sample_case_list=case_list.iloc[:3,:]
sample_case_list.columns
# Out:
# Index(['index', 'datanumber', 'title', 'casenumber', 'date', 'verdicttype',
#        'holding', 'summary', 'jmreference', 'prreference', 'prny'],
#       dtype='object')

# %%
sample_case_list
# Out:
#    index  datanumber      title   casenumber      date verdicttype  \
# 0      0      230881    소유권이전등기  2021다216766  20220831          판결
# 1      1      230867        보험금  2018다304014  20220831          판결
# 2      2      230871  통신비밀보호법위반    2020도1007  20220831          판결
#
#                                              holding  \
# 0    [1] 1975. 12. 31. 지적법 개정 전에 복구된 구 토지대장이나 분배농...
# 1    甲 자산운용회사가 乙 보험회사와 체결한 자산운용전문인 배상책임보험계약의 계약서 ...
# 2  통신비밀보호법 제14조 제1항의 금지를 위반하는 행위는 같은 법 제3조 제1항 위반...
#
#                                              summary  \
# 0    [1] 1975. 12. 31. 지적법 개정 전에 복구된 구 토지대장상의 소유자...
# 1    甲 자산운용회사가 乙 보험회사와 체결한 자산운용전문인 배상책임보험계약의 계약서 ...
# 2    통신비밀보호법은 공개되지 않은 타인 간의 대화에 관하여 다음과 같이 정하고 있다...
#
#                                          jmreference  \
# 0   [1] 민법 제186조$ 민사소송법 제202조$ 구 지적법(1975. 12. 31...
# 1                                           민법 제105조
# 2                통신비밀보호법 제3조 제1항$ 제14조 제1항$ 제16조 제1항
#
#                                          prreference  \
# 0   [1] 대법원 2013. 6. 27. 선고 2012다91354 판결$ 대법원 20...
# 1                                                  -
# 2  대법원 2006. 10. 12. 선고 2006도4981 판결(공2006하$ 1939...
#
#                                                 prny
# 0  【원고$ 피상고인】 원고【피    고】 피고【피고보조참가인$ 상고인】 피고보조참가인...
# 1  【원고$ 피상고인】 칸서스자산운용 주식회사 (소송대리인 법무법인(유한) 지평 담당변...
# 2  【피 고 인】 피고인【상 고 인】 피고인【원심판결】 부산고법 2020. 1. 9. ...

# %%
sample_case_list['datanumber']
# Out:
# 0    230881
# 1    230867
# 2    230871
# Name: datanumber, dtype: int64

# %%
import random

next_id=pd.DataFrame([random.randint(100000,999999)]*3,columns=['next_id'])
next_id.shape
# Out:
# (3, 1)

# %%
sample_case_list_wni=pd.concat([sample_case_list,next_id],axis=1)
sample_case_list_wni
# Out:
#    index  datanumber      title   casenumber      date verdicttype  \
# 0      0      230881    소유권이전등기  2021다216766  20220831          판결
# 1      1      230867        보험금  2018다304014  20220831          판결
# 2      2      230871  통신비밀보호법위반    2020도1007  20220831          판결
#
#                                              holding  \
# 0    [1] 1975. 12. 31. 지적법 개정 전에 복구된 구 토지대장이나 분배농...
# 1    甲 자산운용회사가 乙 보험회사와 체결한 자산운용전문인 배상책임보험계약의 계약서 ...
# 2  통신비밀보호법 제14조 제1항의 금지를 위반하는 행위는 같은 법 제3조 제1항 위반...
#
#                                              summary  \
# 0    [1] 1975. 12. 31. 지적법 개정 전에 복구된 구 토지대장상의 소유자...
# 1    甲 자산운용회사가 乙 보험회사와 체결한 자산운용전문인 배상책임보험계약의 계약서 ...
# 2    통신비밀보호법은 공개되지 않은 타인 간의 대화에 관하여 다음과 같이 정하고 있다...
#
#                                          jmreference  \
# 0   [1] 민법 제186조$ 민사소송법 제202조$ 구 지적법(1975. 12. 31...
# 1                                           민법 제105조
# 2                통신비밀보호법 제3조 제1항$ 제14조 제1항$ 제16조 제1항
#
#                                          prreference  \
# 0   [1] 대법원 2013. 6. 27. 선고 2012다91354 판결$ 대법원 20...
# 1                                                  -
# 2  대법원 2006. 10. 12. 선고 2006도4981 판결(공2006하$ 1939...
#
#                                                 prny  next_id
# 0  【원고$ 피상고인】 원고【피    고】 피고【피고보조참가인$ 상고인】 피고보조참가인...   256025
# 1  【원고$ 피상고인】 칸서스자산운용 주식회사 (소송대리인 법무법인(유한) 지평 담당변...   256025
# 2  【피 고 인】 피고인【상 고 인】 피고인【원심판결】 부산고법 2020. 1. 9. ...   256025

# %%
import re
summarys=[]
jmreferences=[]
for i in range(3):
    summary=re.sub('법','<highlighted>법</highlighted>',sample_case_list.loc[i,'summary'])
    jmreference=re.sub('법','<highlighted>법</highlighted>',sample_case_list.loc[i,'jmreference'])
    
    summarys.append(summary)
    jmreferences.append(jmreference)
    
summ_jm=pd.concat([pd.DataFrame(summarys,columns=["summary_textrank"]),pd.DataFrame(jmreferences,columns=['jmreference_textrank'])],axis=1)
summ_jm
# Out:
#                                     summary_textrank  \
# 0    [1] 1975. 12. 31. 지적<highlighted>법</highligh...
# 1    甲 자산운용회사가 乙 보험회사와 체결한 자산운용전문인 배상책임보험계약의 계약서 ...
# 2    통신비밀보호<highlighted>법</highlighted>은 공개되지 않은 ...
#
#                                 jmreference_textrank
# 0   [1] 민<highlighted>법</highlighted> 제186조$ 민사소송...
# 1                민<highlighted>법</highlighted> 제105조
# 2  통신비밀보호<highlighted>법</highlighted> 제3조 제1항$ 제1...

# %%
sample_case_list_wtr=pd.concat([sample_case_list_wni,summ_jm],axis=1)
sample_case_list_wtr
# Out:
#    index  datanumber      title   casenumber      date verdicttype  \
# 0      0      230881    소유권이전등기  2021다216766  20220831          판결
# 1      1      230867        보험금  2018다304014  20220831          판결
# 2      2      230871  통신비밀보호법위반    2020도1007  20220831          판결
#
#                                              holding  \
# 0    [1] 1975. 12. 31. 지적법 개정 전에 복구된 구 토지대장이나 분배농...
# 1    甲 자산운용회사가 乙 보험회사와 체결한 자산운용전문인 배상책임보험계약의 계약서 ...
# 2  통신비밀보호법 제14조 제1항의 금지를 위반하는 행위는 같은 법 제3조 제1항 위반...
#
#                                              summary  \
# 0    [1] 1975. 12. 31. 지적법 개정 전에 복구된 구 토지대장상의 소유자...
# 1    甲 자산운용회사가 乙 보험회사와 체결한 자산운용전문인 배상책임보험계약의 계약서 ...
# 2    통신비밀보호법은 공개되지 않은 타인 간의 대화에 관하여 다음과 같이 정하고 있다...
#
#                                          jmreference  \
# 0   [1] 민법 제186조$ 민사소송법 제202조$ 구 지적법(1975. 12. 31...
# 1                                           민법 제105조
# 2                통신비밀보호법 제3조 제1항$ 제14조 제1항$ 제16조 제1항
#
#                                          prreference  \
# 0   [1] 대법원 2013. 6. 27. 선고 2012다91354 판결$ 대법원 20...
# 1                                                  -
# 2  대법원 2006. 10. 12. 선고 2006도4981 판결(공2006하$ 1939...
#
#                                                 prny  next_id  \
# 0  【원고$ 피상고인】 원고【피    고】 피고【피고보조참가인$ 상고인】 피고보조참가인...   256025
# 1  【원고$ 피상고인】 칸서스자산운용 주식회사 (소송대리인 법무법인(유한) 지평 담당변...   256025
# 2  【피 고 인】 피고인【상 고 인】 피고인【원심판결】 부산고법 2020. 1. 9. ...   256025
#
#                                     summary_textrank  \
# 0    [1] 1975. 12. 31. 지적<highlighted>법</highligh...
# 1    甲 자산운용회사가 乙 보험회사와 체결한 자산운용전문인 배상책임보험계약의 계약서 ...
# 2    통신비밀보호<highlighted>법</highlighted>은 공개되지 않은 ...
#
#                                 jmreference_textrank
# 0   [1] 민<highlighted>법</highlighted> 제186조$ 민사소송...
# 1                민<highlighted>법</highlighted> 제105조
# 2  통신비밀보호<highlighted>법</highlighted> 제3조 제1항$ 제1...

# %%
kobart=[]
for i in range(3):
    kobart.append(sample_case_list.loc[i,'jmreference']+sample_case_list.loc[i,'summary'])
sample_case_list_wkb=pd.concat([sample_case_list_wtr,pd.DataFrame(kobart,columns=['kobart']),pd.DataFrame(kobart,columns=['_'])],axis=1)
sample_case_list_wkb
# Out:
#    index  datanumber      title   casenumber      date verdicttype  \
# 0      0      230881    소유권이전등기  2021다216766  20220831          판결
# 1      1      230867        보험금  2018다304014  20220831          판결
# 2      2      230871  통신비밀보호법위반    2020도1007  20220831          판결
#
#                                              holding  \
# 0    [1] 1975. 12. 31. 지적법 개정 전에 복구된 구 토지대장이나 분배농...
# 1    甲 자산운용회사가 乙 보험회사와 체결한 자산운용전문인 배상책임보험계약의 계약서 ...
# 2  통신비밀보호법 제14조 제1항의 금지를 위반하는 행위는 같은 법 제3조 제1항 위반...
#
#                                              summary  \
# 0    [1] 1975. 12. 31. 지적법 개정 전에 복구된 구 토지대장상의 소유자...
# 1    甲 자산운용회사가 乙 보험회사와 체결한 자산운용전문인 배상책임보험계약의 계약서 ...
# 2    통신비밀보호법은 공개되지 않은 타인 간의 대화에 관하여 다음과 같이 정하고 있다...
#
#                                          jmreference  \
# 0   [1] 민법 제186조$ 민사소송법 제202조$ 구 지적법(1975. 12. 31...
# 1                                           민법 제105조
# 2                통신비밀보호법 제3조 제1항$ 제14조 제1항$ 제16조 제1항
#
#                                          prreference  \
# 0   [1] 대법원 2013. 6. 27. 선고 2012다91354 판결$ 대법원 20...
# 1                                                  -
# 2  대법원 2006. 10. 12. 선고 2006도4981 판결(공2006하$ 1939...
#
#                                                 prny  next_id  \
# 0  【원고$ 피상고인】 원고【피    고】 피고【피고보조참가인$ 상고인】 피고보조참가인...   256025
# 1  【원고$ 피상고인】 칸서스자산운용 주식회사 (소송대리인 법무법인(유한) 지평 담당변...   256025
# 2  【피 고 인】 피고인【상 고 인】 피고인【원심판결】 부산고법 2020. 1. 9. ...   256025
#
#                                     summary_textrank  \
# 0    [1] 1975. 12. 31. 지적<highlighted>법</highligh...
# 1    甲 자산운용회사가 乙 보험회사와 체결한 자산운용전문인 배상책임보험계약의 계약서 ...
# 2    통신비밀보호<highlighted>법</highlighted>은 공개되지 않은 ...
#
#                                 jmreference_textrank  \
# 0   [1] 민<highlighted>법</highlighted> 제186조$ 민사소송...
# 1                민<highlighted>법</highlighted> 제105조
# 2  통신비밀보호<highlighted>법</highlighted> 제3조 제1항$ 제1...
#
#                                               kobart  \
# 0   [1] 민법 제186조$ 민사소송법 제202조$ 구 지적법(1975. 12. 31...
# 1  민법 제105조  甲 자산운용회사가 乙 보험회사와 체결한 자산운용전문인 배상책임보험...
# 2  통신비밀보호법 제3조 제1항$ 제14조 제1항$ 제16조 제1항  통신비밀보호법은 ...
#
#                                                    _
# 0   [1] 민법 제186조$ 민사소송법 제202조$ 구 지적법(1975. 12. 31...
# 1  민법 제105조  甲 자산운용회사가 乙 보험회사와 체결한 자산운용전문인 배상책임보험...
# 2  통신비밀보호법 제3조 제1항$ 제14조 제1항$ 제16조 제1항  통신비밀보호법은 ...

# %%
sample_case_list_wkb['datanumber']=sample_case_list_wkb['datanumber'].apply(int)
sample_case_list_wkb['next_id']=sample_case_list_wkb['next_id'].apply(int)
sample_case_list_wkb.to_csv('sample_case_list.csv',index=False)

# %% [markdown]
# ## deprecated - changing delimiter

# %%
def into_row(li, delimiter=':'):
    res=''
    for i in li:
        try:
            res+=i
        except:
            res+=str(i)
        res+=delimiter 
    return res[:-1]
sample_case_list_wdl=[]
for row in sample_case_list_wkb.values[:,1:]:
    sample_case_list_wdl.append(into_row(row[1:]))

print(sample_case_list_wdl)
with open('sample_case_list_wdel.txt','w') as f:
    f.writelines(sample_case_list_wdl)
# Out:
# ['2017다292718:20220819:판결:  승진발령이 무효임에도 근로자가 승진발령이 유효함을 전제로 승진된 직급에 따라 계속 근무한 경우$ 승진 후 제공된 근로의 가치가 승진 전과 실질적 차이가 없음에도 단지 직급의 상승만을 이유로 임금이 상승한 부분이 있다면$ 근로자가 이를 부당이득으로 사용자에게 반환하여야 하는지 여부(적극) 및 여기서 승진 전후 제공된 근로의 가치 사이에 실질적으로 차이가 있는지 판단하는 기준:  승진발령이 무효임에도 근로자가 승진발령이 유효함을 전제로 승진된 직급에 따라 계속 근무하여 온 경우$ 승진 전후 각 직급에 따라 수행하는 업무에 차이가 있어 승진된 직급에 따른 업무를 수행하고 그에 대한 대가로 임금이 지급되었다면$ 근로자가 지급받은 임금은 제공된 근로의 대가이므로 근로자에게 실질적인 이득이 있다고 볼 수 없어 사용자가 이에 대해 부당이득으로 반환을 청구할 수 없다. 그러나 승진 전후 각 직급에 따라 수행하는 업무에 차이가 없어 승진 후 제공된 근로의 가치가 승진 전과 견주어 실질적 차이가 없음에도 단지 직급의 상승만을 이유로 임금이 상승한 부분이 있다면$ 근로자는 임금 상승분 상당의 이익을 얻었다고 볼 수 있고$ 승진이 무효인 이상 그 이득은 근로자에게 법률상 원인 없이 지급된 것으로서 부당이득으로 사용자에게 반환되어야 한다. 여기서 승진 전후 제공된 근로의 가치 사이에 실질적으로 차이가 있는지는 제공된 근로의 형태와 수행하는 업무의 내용$ 보직의 차이 유무$ 직급에 따른 권한과 책임의 정도 등 여러 사정을 종합적이고 객관적으로 평가하여 판단하여야 한다.:근로기준법 제2조 제1항 제5호$ 민법 제741조:-:【원고$ 상고인】 한국농어촌공사 (소송대리인 법무법인(유한) 세종 담당변호사 김동욱 외 1인)【피고$ 피상고인】 피고 1 외 23인 (소송대리인 법무법인 열린법률 외 3인)【